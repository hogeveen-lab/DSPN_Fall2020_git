# %% [markdown]
# # Leaky integrate-and-fire with fixed stim duration

# %%
import matplotlib.pyplot as plt
import numpy as np

%% = lines you need to replace

# membrane capacitance & resistance constants
%% membrane time constant = ??
%% threshold = ??
%% resistance = ??

# time step, simulation time, and I timing
dt = 1
max_time = 150
start_stim = 25
stim_dur =75

# Initial values
t = [0]
I = [0]
V = [0]
spike = [0]

# Iterating through to update the lists
for i in range(t[0],max_time,dt):
    %% nt = equation # New time = Current t[i] plus change in t (i.e., dt)
    t.append(nt) # append new time to the time list
    # Conditional expression to update I ~ time
    if t[i] < start_stim: # if current time (t[i]) is less than the start of stimulation, then...
        %% I.append(value) #what value should I be if this condition is met?
    elif (t[i] >= start_stim) & (t[i] <= start_stim+stim_dur): # if current time (t[i]) is greater than the start of stim or the total stim duration timing, then...
        %% I.append(value) #what value should I be if this condition is met?
    else: # after the total stim duration timing has been reached, then...
        %% I.append(value) #what value should I be if neither of the above conditions are met?
    # Conditional expression to update spikes & V
    %% if condition A: # What condition has to be met for us to update V based on the Integrate & Fire equation?
        %% spike.append(value) # What value is the spike variable when the above condition is true?
        %% dv = equation # Change in V (i.e., dv) = leaky integrate & fire equation
        %% nv = equation # New V = Current V[i] plus change in V (i.e., dv)
    %% elif condition B: # what is the opposite condition that might be met?
        %% spike.append(value) # what value should be here?
        %% nv = value # what value should be here?
    V.append(nv) # append new voltage to the voltage list (make sure this matches the if / elif indent level once you've fixed those lines)

# %%
# Plotting the data
plt.figure(1) #Voltage and Current vs time
plt.plot(t,V, 'b')
plt.plot(t,I, 'g')
plt.xlabel('time')
plt.ylabel('V')
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.rcParams.update({'font.size': 18})
plt.rcParams['figure.figsize'] = [20,10]
plt.show()

# Counting the supra-threshold spikes
print('there were a total of:',sum(spike),'spikes above threshold given the stim parameters')
# Out:
# there were a total of: 4 spikes above threshold given the stim parameters
